# %% [markdown]
# # Experiment 1 - Difference Between Scripting and Interactive Modes In IDLE

# %%
#Q1 - For Installing Python You Can Go To Microsoft Store and in the serach bar write Python then u can install Python
#In Script Mode we can excute the code line By Line But in Interactive Mode We can run the program directely in the Terminal

# %%
# Q2- For Writing The Strings In The Given Manner - a-
print("Hello Everyone !!!")
#b-
print("Hello\nWorld")
#c-
print("Hello\n\nWorld")
#d-
print("'Rohit\'s date of birth is 12\\05\\1999")
# Out:
# Hello Everyone !!!
# Hello
# World
# Hello
#
# World
# 'Rohit's date of birth is 12\05\1999

# %%
# Q3- Declare a string variable called x and assign it the value “Hello”. Print out the value of x
x="Hello"
print(x)
# Out:
# Hello

# %%
#Q4 - Take different data types and print values using print function.
age=19
height=6.1
name="Akshat"
is_Trader=True
print(age)
print(height)
print(name)
print(is_Trader)
# Out:
# 19
# 6.1
# Akshat
# True

# %%
#Q5- Take two variables, a and b. Assign your first name and last name. Print your Name after adding your First name and Last name together.
a="Akshat"
b="Jain"
f_name=a+" "+b
print(f_name)
# Out:
# Akshat Jain

# %%
#Q6- Declare three variables, consisting of your first name, your last name and Nickname. Write a program that prints out your first name, then your nickname in parenthesis and then your last name. 
a="Akshat"
b="Jain"
c="Lov"
final=a+" (" + c +") " + b
print(final)
# Out:
# Akshat (Lov) Jain

# %%
#Q7- Declare and assign values to suitable variables and print in the following way:
n="NIKUNJ BANSAL"
s=500069944
d=" 13 Oct 1999 "
a="UPES Bidholi Campus Pincode: 248007"
p="AI & ML"
sem=2
print(f"NAME: {n}")
print(f"SAP ID: {s}")
print(f"DATE OF BIRTH: {d}")
print(f"Address: {a}")
print(f"Programme: {p}")
print(f"Semester: {sem}")
# Out:
# NAME: NIKUNJ BANSAL
# SAP ID: 500069944
# DATE OF BIRTH:  13 Oct 1999
# Address: UPES Bidholi Campus Pincode: 248007
# Programme: AI & ML
# Semester: 2
