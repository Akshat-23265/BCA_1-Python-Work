# %% [markdown]
# # Experiment 6: Lists, tuples, dictionary

# %%
# Q1. Scan n values in range 0-3 and print the number of times each value has occurred

n = int(input("Enter number of values: "))
lst = []

for i in range(n):
    lst.append(int(input()))

for i in range(4):
    print(i, "occurs", lst.count(i), "times")
# Out:
# 0 occurs 0 times
# 1 occurs 0 times
# 2 occurs 0 times
# 3 occurs 0 times

# %%
# Q2. Create a tuple to store n numeric values and find the average of all values

n = int(input("Enter number of values: "))
lst = []

for i in range(n):
    lst.append(float(input()))

t = tuple(lst)
avg = sum(t) / len(t)

print("Average:", avg)
# Out:
# Average: 5795.0

# %%
# Q3. Input a list of scores and print runner-up score

n = int(input("Enter number of students: "))
scores = list(map(int, input("Enter scores: ").split()))

unique_scores = list(set(scores))
unique_scores.sort()

if len(unique_scores) < 2:
    print("No runner-up score exists.")
else:
    print(unique_scores[-2])
# Out:
# No runner-up score exists.

# %%
# Q4. Create a dictionary of n persons where key is name and value is city

n = int(input("Enter number of persons: "))
d = {}

for i in range(n):
    name = input("Enter name: ")
    city = input("Enter city: ")
    d[name] = city

print("Names:")
for name in d.keys():
    print(name)

print("Cities:")
for city in d.values():
    print(city)

print("Name and City:")
for name, city in d.items():
    print(name, "-", city)

city_count = {}

for city in d.values():
    city_count[city] = city_count.get(city, 0) + 1

print("Number of students in each city:")
for city, count in city_count.items():
    print(city, ":", count)
# Out:
# Names:
# Akshat
# Arpit
# ram
# Cities:
# Kanpur
# Lko
# kol
# Name and City:
# Akshat - Kanpur
# Arpit - Lko
# ram - kol
# Number of students in each city:
# Kanpur : 1
# Lko : 1
# kol : 1

# %%
# Q5. Store details of n movies in a dictionary and perform operations

n = int(input("Enter number of movies: "))
movies = {}

for i in range(n):
    name = input("Enter movie name: ")
    year = int(input("Enter release year: "))
    director = input("Enter director name: ")
    cost = float(input("Enter production cost: "))
    earning = float(input("Enter collection made: "))

    movies[name] = {
        "year": year,
        "director": director,
        "cost": cost,
        "earning": earning
    }

print("All movie details:")
for name, details in movies.items():
    print(name, details)

print("Movies released before 2015:")
for name, details in movies.items():
    if details["year"] < 2015:
        print(name)

print("Movies that made profit:")
for name, details in movies.items():
    if details["earning"] > details["cost"]:
        print(name)

dname = input("Enter director name to search: ")

print("Movies directed by", dname + ":")
for name, details in movies.items():
    if details["director"] == dname:
        print(name)
# Out:
# All movie details:
# Dhurander {'year': 2025, 'director': 'No Idea', 'cost': 50000.0, 'earning': 100000.0}
# Yeh Jawani Hai Diwani {'year': 2015, 'director': 'some one', 'cost': 120000.0, 'earning': 500000.0}
# Movies released before 2015:
# Movies that made profit:
# Dhurander
# Yeh Jawani Hai Diwani
# Movies directed by some one:
# Yeh Jawani Hai Diwani
